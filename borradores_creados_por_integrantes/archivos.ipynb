# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# # Beneficiarios ANID
#
# Cantidad de proyectos beneficiarios de ANID, distribución porcentual y brecha de género, según sexo del responsable del proyecto, años 2015 a 2022.

# %%
path_anid = os.path.join('data', 'excel', 'anid.xlsx')

df_anid = pd.read_excel(path_anid, skiprows=2)
df_anid = df_anid.iloc[:8]
df_anid = df_anid.drop(columns='Proyectos beneficiarios liderados por hombres o mujeres\n (Total)')
df_anid
# Out:
#   Año de fallo (6)  Proyectos beneficiarios liderados por hombres \n(Total)  \
# 0             2015                                             2578.0
# 1             2016                                             2301.0
# 2             2017                                             2514.0
# 3             2018                                             2394.0
# 4             2019                                             2447.0
# 5             2020                                             2015.0
# 6             2021                                             1914.0
# 7             2022                                             2273.0
#
#    Proyectos beneficiarios liderados por mujeres\n (Total)  \
# 0                                             1545.0
# 1                                             1421.0
# 2                                             1626.0
# 3                                             1573.0
# 4                                             1642.0
# ...

# %%
columnas = ['Año', 'Beneficiarios por Hombres', 'Beneficiarios por Mujeres', 'Porcentaje Beneficiarios por Hombres', 'Porcentaje Beneficiarios por Mujeres', 'Brecha de Genero']
df_anid.columns = columnas
df_anid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Año                                   8 non-null      object
#  1   Beneficiarios por Hombres             8 non-null      float64
#  2   Beneficiarios por Mujeres             8 non-null      float64
#  3   Porcentaje Beneficiarios por Hombres  8 non-null      float64
#  4   Porcentaje Beneficiarios por Mujeres  8 non-null      float64
#  5   Brecha de Genero                      8 non-null      float64
# dtypes: float64(5), object(1)
# memory usage: 516.0+ bytes

# %%
df_anid = df_anid.round(3)
df_anid['Año'] = df_anid['Año'].astype(int)
df_anid
# Out:
#     Año  Beneficiarios por Hombres  Beneficiarios por Mujeres  \
# 0  2015                     2578.0                     1545.0
# 1  2016                     2301.0                     1421.0
# 2  2017                     2514.0                     1626.0
# 3  2018                     2394.0                     1573.0
# 4  2019                     2447.0                     1642.0
# 5  2020                     2015.0                     1272.0
# 6  2021                     1914.0                     1148.0
# 7  2022                     2273.0                     1613.0
#
#    Porcentaje Beneficiarios por Hombres  Porcentaje Beneficiarios por Mujeres  \
# 0                                 0.625                                 0.375
# 1                                 0.618                                 0.382
# 2                                 0.607                                 0.393
# 3                                 0.603                                 0.397
# ...

# %%
plt.figure(figsize=(12, 8))
plt.plot(df_anid['Año'], df_anid['Beneficiarios por Hombres'], marker='o', label='Hombres', color='blue')
plt.plot(df_anid['Año'], df_anid['Beneficiarios por Mujeres'], marker='x', label='Mujeres', color='pink')

plt.title("Beneficiarios de ANID por género a lo largo de los años")
plt.xlabel("Año")
plt.ylabel("Número de Beneficiarios")
plt.xticks(df_anid['Año'])
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Beneficiarios CORFO
#
# Cantidad de proyectos beneficiarios del Comité InnovaChile (Corfo), distribución porcentual y brecha de género, según sexo del responsable de proyecto, años 2011 a 2022.

# %%
path_corfo = os.path.join('data', 'excel', 'corfo.xlsx')

df_corfo = pd.read_excel(path_corfo, skiprows=2)
df_corfo = df_corfo.iloc[:12]
df_corfo = df_corfo.drop(columns='Proyectos beneficiarios liderados por hombres o mujeres \n(Total)')
df_corfo
# Out:
#    Año de fallo (5)  Proyectos beneficiarios liderados por hombres \n(Total)  \
# 0              2011                                              612.0
# 1              2012                                              523.0
# 2              2013                                              212.0
# 3              2014                                              301.0
# 4              2015                                              528.0
# 5              2016                                              583.0
# 6              2017                                              677.0
# 7              2018                                              419.0
# 8              2019                                              301.0
# 9              2020                                              367.0
# 10             2021                                              512.0
# 11             2022                                              308.0
#
# ...

# %%
columnas = ['Año', 'Beneficiarios por Hombres', 'Beneficiarios por Mujeres', 'Porcentaje Beneficiarios por Hombres', 'Porcentaje Beneficiarios por Mujeres', 'Brecha de Genero']
df_corfo.columns = columnas
df_corfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Año                                   12 non-null     object
#  1   Beneficiarios por Hombres             12 non-null     float64
#  2   Beneficiarios por Mujeres             12 non-null     float64
#  3   Porcentaje Beneficiarios por Hombres  12 non-null     float64
#  4   Porcentaje Beneficiarios por Mujeres  12 non-null     float64
#  5   Brecha de Genero                      12 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 708.0+ bytes

# %%
df_corfo = df_corfo.round(3)
df_corfo['Año'] = df_corfo['Año'].astype(int)
df_corfo
# Out:
#      Año  Beneficiarios por Hombres  Beneficiarios por Mujeres  \
# 0   2011                      612.0                      228.0
# 1   2012                      523.0                      227.0
# 2   2013                      212.0                       67.0
# 3   2014                      301.0                       98.0
# 4   2015                      528.0                      132.0
# 5   2016                      583.0                      181.0
# 6   2017                      677.0                      284.0
# 7   2018                      419.0                      185.0
# 8   2019                      301.0                      112.0
# 9   2020                      367.0                      129.0
# 10  2021                      512.0                      214.0
# 11  2022                      308.0                      141.0
#
#     Porcentaje Beneficiarios por Hombres  \
# 0                                  0.729
# 1                                  0.697
# ...

# %%
plt.figure(figsize=(12, 8))
plt.plot(df_corfo['Año'], df_corfo['Beneficiarios por Hombres'], marker='o', label='Hombres', color='blue')
plt.plot(df_corfo['Año'], df_corfo['Beneficiarios por Mujeres'], marker='x', label='Mujeres', color='pink')

plt.title("Beneficiarios de CORFO por género a lo largo de los años")
plt.xlabel("Año")
plt.ylabel("Número de Beneficiarios")
plt.xticks(df_corfo['Año'])
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %%
fig, axes = plt.subplots(2, 1, figsize=(12, 12))

axes[0].plot(df_anid['Año'], df_anid['Beneficiarios por Hombres'], marker='o', label='Hombres', color='blue')
axes[0].plot(df_anid['Año'], df_anid['Beneficiarios por Mujeres'], marker='x', label='Mujeres', color='pink')
axes[0].set_title("Beneficiarios por género (ANID)")
axes[0].set_xlabel("Año")
axes[0].set_ylabel("Número de Beneficiarios")
axes[0].legend(loc='best')
axes[0].grid(alpha=0.3)

axes[1].plot(df_corfo['Año'], df_corfo['Beneficiarios por Hombres'], marker='o', label='Hombres', color='blue')
axes[1].plot(df_corfo['Año'], df_corfo['Beneficiarios por Mujeres'], marker='x', label='Mujeres', color='pink')
axes[1].set_title("Beneficiarios por género (CORFO)")
axes[1].set_xlabel("Año")
axes[1].set_ylabel("Número de Beneficiarios")
axes[1].legend(loc='best')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Embarazo No Planificado
#
# Porcentaje de mujeres y hombres jóvenes iniciados sexualmente que vivieron un embarazo no planificado, según sexo y año.

# %%
path_noplanificado = os.path.join('data', 'excel', 'embarazo_noplanificado.xlsx')

df_noplanificado = pd.read_excel(path_noplanificado, skiprows=2)
df_noplanificado = df_noplanificado.iloc[:7]
df_noplanificado = df_noplanificado.drop(columns='Unnamed: 1')
df_noplanificado
# Out:
#   Año(⁴) Porcentaje de mujeres Porcentaje de hombres  Brecha
# 0    NaN                   (%)                   (%)     (%)
# 1   2006                 42.03                18.193 -23.837
# 2   2009                41.768                18.412 -23.356
# 3   2012                27.471                 15.46 -12.011
# 4   2015                 26.84                 17.68   -9.16
# 5   2018                 23.79                 10.45  -13.34
# 6   2022                  26.3                    13   -13.3

# %%
columnas = ['Año', 'Porcentaje de Mujeres %', 'Porcentaje de Hombres %', 'Brecha']
df_noplanificado.columns = columnas
df_noplanificado = df_noplanificado.dropna()
df_noplanificado['Año'] = df_noplanificado['Año'].astype(int)
df_noplanificado['Porcentaje de Mujeres %'] = df_noplanificado['Porcentaje de Mujeres %'].astype(float)
df_noplanificado['Porcentaje de Hombres %'] = df_noplanificado['Porcentaje de Hombres %'].astype(float)
df_noplanificado['Brecha'] = df_noplanificado['Brecha'].astype(float)
df_noplanificado
# Out:
# C:\Users\vbele\AppData\Local\Temp\ipykernel_14368\254259198.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_noplanificado['Año'] = df_noplanificado['Año'].astype(int)
# C:\Users\vbele\AppData\Local\Temp\ipykernel_14368\254259198.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_noplanificado['Porcentaje de Mujeres %'] = df_noplanificado['Porcentaje de Mujeres %'].astype(float)
# C:\Users\vbele\AppData\Local\Temp\ipykernel_14368\254259198.py:6: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(12, 8))
plt.plot(df_noplanificado['Año'], df_noplanificado['Porcentaje de Hombres %'], marker='o', label='Hombres', color='blue')
plt.plot(df_noplanificado['Año'], df_noplanificado['Porcentaje de Mujeres %'], marker='x', label='Mujeres', color='pink')

plt.title("Porcentaje de mujeres y hombres jóvenes que vivieron un embarazo no planificado entre los 15 y 29 años")
plt.xlabel("Año")
plt.ylabel("Número de jóvenes")
plt.xticks(df_noplanificado['Año'])
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# # Evolución académicas en general

# %%
path_academicas = os.path.join('data', 'excel', 'evolucion_academica.xlsx')

df_academica = pd.read_excel(path_academicas, skiprows=5)
df_academica = df_academica.iloc[:3]
df_academica.columns = df_academica.columns.fillna('').astype(str)
df_academica = df_academica.loc[:, ~df_academica.columns.str.contains('Unnamed:')]
df_academica
# Out:
#     Género   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  Mujeres  25067  27230  28977  30657  33365  35247  36569  38063  38028
# 1  Hombres  37481  39101  41271  42227  45007  47268  48486  49762  49285
# 2    Total  62548  66331  70248  72884  78372  82515  85055  87825  87313
#
#    ...   2019   2020   2021   2022   2023   2024 %  Variación 2015 - 2024  \
# 0  ...  38393  37956  36956  38845  40470  41538                  0.13588
# 1  ...  47939  47302  45481  46904  48528  49416                 0.019181
# 2  ...  86332  85258  82437  85749  88998  90954                 0.069355
#
#   % Variación 2020 - 2024 % Variación 2023 - 2024 Distribución % 2024
# 0                0.094372                 0.02639            0.456692
# 1                0.044692                0.018299            0.543308
# 2                0.066809                0.021978                   1
#
# [3 rows x 21 columns]

# %%
df_academica.columns
# Out:
# Index(['Género', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024',
#        '%  Variación 2015 - 2024', '% Variación 2020 - 2024',
#        '% Variación 2023 - 2024', 'Distribución % 2024'],
#       dtype='object')

# %%
df_academica = df_academica.drop(df_academica.columns[-4:], axis=1)
df_academica['2009'] = df_academica['2009'].astype(int)
df_academica['2010'] = df_academica['2010'].astype(int)
df_academica['2011'] = df_academica['2011'].astype(int)
df_academica['2012'] = df_academica['2012'].astype(int)
df_academica['2013'] = df_academica['2013'].astype(int)
df_academica['2014'] = df_academica['2014'].astype(int)
df_academica['2015'] = df_academica['2015'].astype(int)
df_academica['2016'] = df_academica['2016'].astype(int)
df_academica['2017'] = df_academica['2017'].astype(int)
df_academica['2018'] = df_academica['2018'].astype(int)
df_academica['2019'] = df_academica['2019'].astype(int)
df_academica['2020'] = df_academica['2020'].astype(int)
df_academica['2021'] = df_academica['2021'].astype(int)
df_academica['2022'] = df_academica['2022'].astype(int)
df_academica['2023'] = df_academica['2023'].astype(int)
df_academica['2024'] = df_academica['2024'].astype(int)
df_academica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Género  3 non-null      object
#  1   2009    3 non-null      int32
#  2   2010    3 non-null      int32
#  3   2011    3 non-null      int32
#  4   2012    3 non-null      int32
#  5   2013    3 non-null      int32
#  6   2014    3 non-null      int32
#  7   2015    3 non-null      int32
#  8   2016    3 non-null      int32
#  9   2017    3 non-null      int32
#  10  2018    3 non-null      int32
#  11  2019    3 non-null      int32
#  12  2020    3 non-null      int32
#  13  2021    3 non-null      int32
#  14  2022    3 non-null      int32
#  15  2023    3 non-null      int32
#  16  2024    3 non-null      int32
# dtypes: int32(16), object(1)
# memory usage: 348.0+ bytes

# %%
df_academica
# Out:
#     Género   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  Mujeres  25067  27230  28977  30657  33365  35247  36569  38063  38028
# 1  Hombres  37481  39101  41271  42227  45007  47268  48486  49762  49285
# 2    Total  62548  66331  70248  72884  78372  82515  85055  87825  87313
#
#     2018   2019   2020   2021   2022   2023   2024
# 0  38125  38393  37956  36956  38845  40470  41538
# 1  48436  47939  47302  45481  46904  48528  49416
# 2  86561  86332  85258  82437  85749  88998  90954

# %%
df_academica = df_academica.set_index('Género').transpose()
plt.figure(figsize=(12, 8))
plt.plot(df_academica.index, df_academica['Mujeres'], marker='o', label='Mujeres', color='pink')
plt.plot(df_academica.index, df_academica['Hombres'], marker='x', label='Hombres', color='blue')
plt.title("Número de Academicas/os por Año")
plt.xlabel("Año")
plt.ylabel("Número de personas")
plt.xticks(rotation=45)
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
