# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
archivo = os.path.join('data', 'excel', "SIMCE-matematicas-II-medio-Nacional-y-regional-1-1-1-2023.xlsx")
xl = pd.ExcelFile(archivo)
print(xl.sheet_names)
# Out:
# ['PRESENTACIÓN', 'NACIONAL', 'REGIONAL']

# %%
datos_nacional = pd.read_excel(archivo, sheet_name="NACIONAL", skiprows=2)
datos_regional = pd.read_excel(archivo, sheet_name="REGIONAL",  skiprows=2)
datos_nacional = datos_nacional.drop(index=[12, 13,14,15])
datos_nacional
# Out:
#      Año  Puntaje SIMCE de matemáticas hombres \n(puntos)  \
# 0   2006                                            257.0
# 1   2008                                            254.0
# 2   2010                                            260.0
# 3   2012                                            269.0
# 4   2013                                            271.0
# 5   2014                                            267.0
# 6   2015                                            263.0
# 7   2016                                            267.0
# 8   2017                                            267.0
# 9   2018                                            266.0
# 10  2022                                            255.0
# 11  2023                                            262.0
#
#     Puntaje SIMCE de matemáticas mujeres\n(puntos)  \
# 0                                            247.0
# 1                                            246.0
# 2                                            251.0
# ...

# %%
datos_nacional["Puntaje SIMCE de matemáticas hombres \n(puntos)"] = datos_nacional["Puntaje SIMCE de matemáticas hombres \n(puntos)"].astype(int)
datos_nacional["Puntaje SIMCE de matemáticas mujeres\n(puntos)"] = datos_nacional["Puntaje SIMCE de matemáticas mujeres\n(puntos)"].astype(int)
datos_nacional["Año"] = datos_nacional["Año"].astype(int)
datos_regional = datos_regional.drop(index=[192, 193,194,195,196])

# %%
plt.figure(figsize=(10, 8))
plt.plot(datos_nacional["Año"], datos_nacional["Puntaje SIMCE de matemáticas hombres \n(puntos)"], marker='o', color='blue', label='Hombres')
plt.plot(datos_nacional["Año"], datos_nacional["Puntaje SIMCE de matemáticas mujeres\n(puntos)"],  marker='x', color='pink', label='Mujeres')
plt.title("Puntajes SIMCE Nacional de matemáticas (Hombres vs Mujeres)", fontsize=14)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Puntajes", fontsize=12)
plt.xticks(datos_nacional["Año"])  
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
datos_regional
# Out:
#       Año              Región  Código región  \
# 0    2006  Arica y Parinacota           15.0
# 1    2008  Arica y Parinacota           15.0
# 2    2010  Arica y Parinacota           15.0
# 3    2012  Arica y Parinacota           15.0
# 4    2013  Arica y Parinacota           15.0
# ..    ...                 ...            ...
# 187  2016          Magallanes           12.0
# 188  2017          Magallanes           12.0
# 189  2018          Magallanes           12.0
# 190  2022          Magallanes           12.0
# 191  2023          Magallanes           12.0
#
#      Puntaje prueba de matemáticas hombres \n(puntos)  \
# 0                                               247.0
# 1                                               251.0
# 2                                               251.0
# 3                                               264.0
# 4                                               260.0
# ..                                                ...
# ...

# %%
datos_regional
# Out:
#       Año              Región  Código región  \
# 0    2006  Arica y Parinacota           15.0
# 1    2008  Arica y Parinacota           15.0
# 2    2010  Arica y Parinacota           15.0
# 3    2012  Arica y Parinacota           15.0
# 4    2013  Arica y Parinacota           15.0
# ..    ...                 ...            ...
# 187  2016          Magallanes           12.0
# 188  2017          Magallanes           12.0
# 189  2018          Magallanes           12.0
# 190  2022          Magallanes           12.0
# 191  2023          Magallanes           12.0
#
#      Puntaje prueba de matemáticas hombres \n(puntos)  \
# 0                                               247.0
# 1                                               251.0
# 2                                               251.0
# 3                                               264.0
# 4                                               260.0
# ..                                                ...
# ...

# %%
datos_regional['Región'].unique()
# Out:
# array(['Arica y Parinacota', 'Tarapacá', 'Antofagasta', 'Atacama',
#        'Coquimbo', 'Valparaíso', 'Metropolitana', 'O´Higgins', 'Maule',
#        'Ñuble', 'Biobío', 'La Araucanía', 'Los Ríos', 'Los Lagos',
#        'Aysén', 'Magallanes'], dtype=object)

# %%
datos_regional["Puntaje prueba de matemáticas hombres \n(puntos)"] = datos_regional["Puntaje prueba de matemáticas hombres \n(puntos)"].astype(int)
datos_regional["Puntaje prueba de matemáticas mujeres  \n(puntos)"] = datos_regional["Puntaje prueba de matemáticas mujeres  \n(puntos)"].astype(int)
datos_regional["Año"] = datos_regional["Año"].astype(int)
datos_regional["Código región"] = datos_regional["Código región"].astype(int)
datos_regional["Brecha de género \n(puntos)"] = datos_regional["Brecha de género \n(puntos)"].astype(int)

# %%
plt.figure(figsize=(10, 8))
plt.plot(datos_nacional["Año"], datos_nacional["Brecha de género \n(puntos)"], marker='o')
plt.title("Evolución de la brecha de género a nivel nacional", fontsize=14)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Brecha de género \n(puntos)", fontsize=12)
plt.xticks(datos_nacional["Año"])
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
regiones_especificas = ["Arica y Parinacota", "Antofagasta", "Atacama", "Tarapacá", "Coquimbo"]
datos_regional_filtrado = datos_regional[datos_regional['Región'].isin(regiones_especificas)]

# %%
df_grouped = datos_regional_filtrado.groupby('Año').agg({ 'Puntaje prueba de matemáticas hombres \n(puntos)': 'mean', 'Puntaje prueba de matemáticas mujeres  \n(puntos)': 'mean' }).reset_index() 
df_grouped.columns = ['Año', 'Puntaje Hombres', 'Puntaje Mujeres']

# %%
plt.figure(figsize=(12, 8))

plt.plot(df_grouped['Año'], df_grouped['Puntaje Hombres'], marker='o', label='Hombres', color='blue')

plt.plot(df_grouped['Año'], df_grouped['Puntaje Mujeres'], marker='x', label='Mujeres', color='pink')

plt.title("Puntajes de prueba simce matemáticas por género en regiones del norte")
plt.xlabel("Año")
plt.ylabel("Puntaje Promedio")
plt.xticks(datos_regional["Año"])  
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
regiones_especificas_2 = ['Valparaíso', 'Metropolitana', "O'Higgins", 'Maule']
datos_regional_filtrado_2 = datos_regional[datos_regional['Región'].isin(regiones_especificas_2)]

# %%
df_grouped = datos_regional_filtrado_2.groupby('Año').agg({ 'Puntaje prueba de matemáticas hombres \n(puntos)': 'mean', 'Puntaje prueba de matemáticas mujeres  \n(puntos)': 'mean' }).reset_index() 
df_grouped.columns = ['Año', 'Puntaje Hombres', 'Puntaje Mujeres']

# %%
plt.figure(figsize=(12, 8))

plt.plot(df_grouped['Año'], df_grouped['Puntaje Hombres'], marker='o', label='Hombres', color='blue')

plt.plot(df_grouped['Año'], df_grouped['Puntaje Mujeres'], marker='x', label='Mujeres', color='pink')

plt.title("Puntajes de prueba simce matemáticas por género en regiones del Centro")
plt.xlabel("Año")
plt.ylabel("Puntaje Promedio")
plt.xticks(datos_regional["Año"])  
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
regiones_especificas_3 = ['Ñuble', 'BioBío', 'La Araucanía', 'Los Ríos', 'Los Lagos', 'Aysén', 'Magallanes']
datos_regional_filtrado_3 = datos_regional[datos_regional['Región'].isin(regiones_especificas_3)]

# %%
df_grouped = datos_regional_filtrado_3.groupby('Año').agg({ 'Puntaje prueba de matemáticas hombres \n(puntos)': 'mean', 'Puntaje prueba de matemáticas mujeres  \n(puntos)': 'mean' }).reset_index() 
df_grouped.columns = ['Año', 'Puntaje Hombres', 'Puntaje Mujeres']

# %%
plt.figure(figsize=(12, 8))

plt.plot(df_grouped['Año'], df_grouped['Puntaje Hombres'], marker='o', label='Hombres', color='blue')

plt.plot(df_grouped['Año'], df_grouped['Puntaje Mujeres'], marker='x', label='Mujeres', color='pink')

plt.title("Puntajes de prueba simce matemáticas por género en regiones del Sur")
plt.xlabel("Año")
plt.ylabel("Puntaje Promedio")
plt.xticks(datos_regional["Año"])  
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Este fue el archivo del simce

# %%
archivo = os.path.join('data', 'excel', "tituladas-carreras-tecnicas-area-tecnologia-nacional-y-regional.xlsx")
xl = pd.ExcelFile(archivo)
print(xl.sheet_names)
# Out:
# ['PRESENTACIÓN', 'NACIONAL', 'REGIONAL']

# %%
datos_nacional = pd.read_excel(archivo, sheet_name="NACIONAL", skiprows=2)
datos_regional = pd.read_excel(archivo, sheet_name="REGIONAL",  skiprows=2)
datos_regional = datos_regional.drop(index=[272, 273,274,275])
datos_nacional = datos_nacional.drop(index=[17, 18,19,20,21])
datos_nacional
# Out:
#      Año  Personas tituladas\n(Total)  Hombres titulados\n(Total)  \
# 0   2007                       5809.0                      4886.0
# 1   2008                       6865.0                      5880.0
# 2   2009                       7670.0                      6513.0
# 3   2010                       7940.0                      6747.0
# 4   2011                      10338.0                      8532.0
# 5   2012                      12393.0                      9978.0
# 6   2013                      15198.0                     12112.0
# 7   2014                      18594.0                     14479.0
# 8   2015                      24396.0                     18227.0
# 9   2016                      26500.0                     19883.0
# 10  2017                      25488.0                     19742.0
# 11  2018                      24579.0                     19661.0
# 12  2019                      21406.0                     18052.0
# ...

# %%
datos_regional
# Out:
#                  Región  Código región     Año  Personas tituladas\n(Total)  \
# 0    Arica y Parinacota           15.0  2007.0                         42.0
# 1    Arica y Parinacota           15.0  2008.0                         73.0
# 2    Arica y Parinacota           15.0  2009.0                         94.0
# 3    Arica y Parinacota           15.0  2010.0                        121.0
# 4    Arica y Parinacota           15.0  2011.0                        131.0
# ..                  ...            ...     ...                          ...
# 267          Magallanes           12.0  2019.0                        262.0
# 268          Magallanes           12.0  2020.0                        132.0
# 269          Magallanes           12.0  2021.0                        215.0
# 270          Magallanes           12.0  2022.0                        233.0
# 271          Magallanes           12.0  2023.0                        242.0
#
# ...

# %% [markdown]
# Este es el de carreras tecnicas

# %%
archivo = os.path.join('data', 'excel', "tituladas-carreras-profesionales-area-tecnologia-nacional-y-regional.xlsx")
xl = pd.ExcelFile(archivo)
print(xl.sheet_names)
# Out:
# ['PRESENTACIÓN', 'NACIONAL', 'REGIONAL']

# %%
datos_nacional = pd.read_excel(archivo, sheet_name="NACIONAL", skiprows=2)
datos_regional = pd.read_excel(archivo, sheet_name="REGIONAL",  skiprows=2)
datos_regional = datos_regional.drop(index=[272, 273,274,275])
datos_nacional = datos_nacional.drop(index=[17, 18,19,20,21])
datos_nacional.head()
# Out:
#     Año  Personas tituladas\n(Total)  Hombres titulados\n(Total)  \
# 0  2007                      13841.0                     10788.0
# 1  2008                      13498.0                     10705.0
# 2  2009                      15801.0                     12569.0
# 3  2010                      15379.0                     12257.0
# 4  2011                      16118.0                     12841.0
#
#    Mujeres tituladas\n(Total)  Porcentaje de hombres titulados\n(%)  \
# 0                      3053.0                             77.942345
# 1                      2793.0                             79.308046
# 2                      3232.0                             79.545598
# 3                      3122.0                             79.699590
# 4                      3277.0                             79.668693
#
#    Porcentaje de mujeres tituladas\n(%)  Brecha de género(2) \n(pp.)
# 0                             22.057655                   -55.884690
# ...

# %%
datos_regional.head()
# Out:
#                Región  Código región     Año  Personas tituladas\n(Total)  \
# 0  Arica y Parinacota           15.0  2007.0                        175.0
# 1  Arica y Parinacota           15.0  2008.0                        158.0
# 2  Arica y Parinacota           15.0  2009.0                        176.0
# 3  Arica y Parinacota           15.0  2010.0                        187.0
# 4  Arica y Parinacota           15.0  2011.0                        221.0
#
#    Hombres titulados\n(Total)  Mujeres tituladas\n(Total)  \
# 0                       148.0                        27.0
# 1                       131.0                        27.0
# 2                       145.0                        31.0
# 3                       151.0                        36.0
# 4                       184.0                        37.0
#
#    Porcentaje de hombres titulados\n(%)  Porcentaje de mujeres tituladas\n(%)  \
# 0                             84.571429                             15.428571
# ...

# %% [markdown]
# Esto fue el de carreras tecnicas

# %%
archivo = os.path.join('data', 'excel', "tituladas-carreras-profesionales-area-tecnologia-nacional-y-regional.xlsx")
xl = pd.ExcelFile(archivo)
print(xl.sheet_names)
# Out:
# ['PRESENTACIÓN', 'NACIONAL', 'REGIONAL']

# %%
datos_nacional = pd.read_excel(archivo, sheet_name="NACIONAL", skiprows=2)
datos_regional = pd.read_excel(archivo, sheet_name="REGIONAL",  skiprows=2)
datos_regional = datos_regional.drop(index=[272, 273,274,275])
datos_nacional = datos_nacional.drop(index=[17, 18,19,20,21])
datos_nacional
# Out:
#      Año  Personas tituladas\n(Total)  Hombres titulados\n(Total)  \
# 0   2007                      13841.0                     10788.0
# 1   2008                      13498.0                     10705.0
# 2   2009                      15801.0                     12569.0
# 3   2010                      15379.0                     12257.0
# 4   2011                      16118.0                     12841.0
# 5   2012                      18886.0                     14821.0
# 6   2013                      23055.0                     17963.0
# 7   2014                      25646.0                     19906.0
# 8   2015                      28273.0                     21844.0
# 9   2016                      29251.0                     22044.0
# 10  2017                      32117.0                     24123.0
# 11  2018                      33492.0                     25280.0
# 12  2019                      30794.0                     23361.0
# ...

# %%
datos_nacional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Año                                  17 non-null     object
#  1   Personas tituladas
# (Total)           17 non-null     float64
#  2   Hombres titulados
# (Total)            17 non-null     float64
#  3   Mujeres tituladas
# (Total)            17 non-null     float64
#  4   Porcentaje de hombres titulados
# (%)  17 non-null     float64
#  5   Porcentaje de mujeres tituladas
# (%)  17 non-null     float64
#  6   Brecha de género(2)
# (pp.)           17 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 1.1+ KB

# %%
datos_regional
# Out:
#                  Región  Código región     Año  Personas tituladas\n(Total)  \
# 0    Arica y Parinacota           15.0  2007.0                        175.0
# 1    Arica y Parinacota           15.0  2008.0                        158.0
# 2    Arica y Parinacota           15.0  2009.0                        176.0
# 3    Arica y Parinacota           15.0  2010.0                        187.0
# 4    Arica y Parinacota           15.0  2011.0                        221.0
# ..                  ...            ...     ...                          ...
# 267          Magallanes           12.0  2019.0                        143.0
# 268          Magallanes           12.0  2020.0                        120.0
# 269          Magallanes           12.0  2021.0                        145.0
# 270          Magallanes           12.0  2022.0                        150.0
# 271          Magallanes           12.0  2023.0                         95.0
#
# ...

# %%
datos_regional = datos_regional.dropna(subset=['Mujeres tituladas\n(Total)', 'Brecha de género (1)\n (pp.)'])

# %%
for col in datos_regional:
    nulos = datos_regional[col].isna().sum()
    #print('-------------------')
    print(f'La columna {col} posee {nulos} nulos')
# Out:
# La columna Región posee 0 nulos
# La columna Código región posee 0 nulos
# La columna Año posee 0 nulos
# La columna Personas tituladas
# (Total) posee 0 nulos
# La columna Hombres titulados
# (Total) posee 0 nulos
# La columna Mujeres tituladas
# (Total) posee 0 nulos
# La columna Porcentaje de hombres titulados
# (%) posee 0 nulos
# La columna Porcentaje de mujeres tituladas
# (%) posee 0 nulos
# La columna Brecha de género (1)
#  (pp.) posee 0 nulos

# %%
datos_regional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271 entries, 0 to 271
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Región                               271 non-null    object
#  1   Código región                        271 non-null    float64
#  2   Año                                  271 non-null    float64
#  3   Personas tituladas
# (Total)           271 non-null    float64
#  4   Hombres titulados
# (Total)            271 non-null    float64
#  5   Mujeres tituladas
# (Total)            271 non-null    float64
#  6   Porcentaje de hombres titulados
# (%)  271 non-null    float64
#  7   Porcentaje de mujeres tituladas
# (%)  271 non-null    float64
#  8   Brecha de género (1)
#  (pp.)          271 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 21.2+ KB

# %%
datos_nacional["Personas tituladas\n(Total)"] = datos_nacional["Personas tituladas\n(Total)"].astype(int)
datos_nacional["Hombres titulados\n(Total)"] = datos_nacional["Hombres titulados\n(Total)"].astype(int)
datos_nacional["Año"] = datos_nacional["Año"].astype(int)
datos_nacional["Mujeres tituladas\n(Total)"] = datos_nacional["Mujeres tituladas\n(Total)"].astype(int)

# %%
datos_regional["Personas tituladas\n(Total)"] = datos_regional["Personas tituladas\n(Total)"].astype(int)
datos_regional["Hombres titulados\n(Total)"] = datos_regional["Hombres titulados\n(Total)"].astype(int)
datos_regional["Año"] = datos_regional["Año"].astype(int)
datos_regional["Código región"] = datos_regional["Código región"].astype(int)
datos_regional["Mujeres tituladas\n(Total)"] = datos_regional["Mujeres tituladas\n(Total)"].astype(int)
# Out:
# C:\Users\vbele\AppData\Local\Temp\ipykernel_7744\1774146631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_regional["Personas tituladas\n(Total)"] = datos_regional["Personas tituladas\n(Total)"].astype(int)
# C:\Users\vbele\AppData\Local\Temp\ipykernel_7744\1774146631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_regional["Hombres titulados\n(Total)"] = datos_regional["Hombres titulados\n(Total)"].astype(int)
# ...

# %%
plt.figure(figsize=(10, 8))
plt.plot(datos_nacional["Año"], datos_nacional["Hombres titulados\n(Total)"], marker='o', color='blue', label='Hombres')
plt.plot(datos_nacional["Año"], datos_nacional["Mujeres tituladas\n(Total)"], marker='x', color='pink', label='Mujeres')
plt.title("Titulados en carreras profesionales STEM (Hombres vs Mujeres)", fontsize=14)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Titulados", fontsize=12)
plt.xticks(datos_nacional["Año"])  
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
regiones_especificas_norte = ["Arica y Parinacota", "Antofagasta", "Atacama", "Tarapacá", "Coquimbo"]
datos_regional_norte = datos_regional[datos_regional['Región'].isin(regiones_especificas_norte)]

# %%
df_grouped = datos_regional_norte.groupby('Año').agg({ 'Hombres titulados\n(Total)': 'mean', 'Mujeres tituladas\n(Total)': 'mean' }).reset_index() 
df_grouped.columns = ['Año', 'Titulados Hombres', 'Tituladas Mujeres']

# %%
plt.figure(figsize=(12, 8))
plt.plot(df_grouped['Año'], df_grouped['Titulados Hombres'], marker='o', label='Hombres', color='blue')
plt.plot(df_grouped['Año'], df_grouped['Tituladas Mujeres'], marker='x', label='Mujeres', color='pink')
plt.title("Titulados carrera profesionales hombres v/s mujeres Zona norte")
plt.xlabel("Año")
plt.ylabel("Cantidad personas")
plt.xticks(datos_regional["Año"])
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
regiones_especificas_centro = ['Valparaíso', 'Metropolitana', "O'Higgins", 'Maule']
datos_regional_filtrado_centro = datos_regional[datos_regional['Región'].isin(regiones_especificas_centro)]

# %%
df_grouped = datos_regional_filtrado_centro.groupby('Año').agg({ 'Hombres titulados\n(Total)': 'mean', 'Mujeres tituladas\n(Total)': 'mean' }).reset_index() 
df_grouped.columns = ['Año', 'Titulados Hombres', 'Tituladas Mujeres']

# %%
plt.figure(figsize=(12, 8))
plt.plot(df_grouped['Año'], df_grouped['Titulados Hombres'], marker='o', label='Hombres', color='blue')
plt.plot(df_grouped['Año'], df_grouped['Tituladas Mujeres'], marker='x', label='Mujeres', color='pink')
plt.title("Titulados carrera Tecnologia hombres v/s mujeres Zona centro")
plt.xlabel("Año")
plt.ylabel("Cantidad personas")
plt.xticks(datos_regional_filtrado_centro["Año"])
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
regiones_especificas_sur = ['Ñuble', 'BioBío', 'La Araucanía', 'Los Ríos', 'Los Lagos', 'Aysén', 'Magallanes']
datos_regional_filtrado_sur = datos_regional[datos_regional['Región'].isin(regiones_especificas_sur)]

# %%
df_grouped = datos_regional_filtrado_sur.groupby('Año').agg({ 'Hombres titulados\n(Total)': 'mean', 'Mujeres tituladas\n(Total)': 'mean' }).reset_index() 
df_grouped.columns = ['Año', 'Titulados Hombres', 'Tituladas Mujeres']

# %%
plt.figure(figsize=(12, 8))
plt.plot(df_grouped['Año'], df_grouped['Titulados Hombres'], marker='o', label='Hombres', color='blue')
plt.plot(df_grouped['Año'], df_grouped['Tituladas Mujeres'], marker='x', label='Mujeres', color='pink')
plt.title("Titulados carrera Tecnologia hombres v/s mujeres Zona sur")
plt.xlabel("Año")
plt.ylabel("Cantidad personas")
plt.xticks(datos_regional["Año"])
plt.legend(loc='best')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
